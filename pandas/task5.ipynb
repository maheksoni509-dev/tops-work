# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\mahek\Downloads\matchscore.csv\matches.csv")

print(df.head())
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
songs_data = pd.read_json("song.json")

print(songs_data)
# Out:
#                  Song             Artist                     Album  \
# 0            Espresso  Sabrina Carpenter            Short n' Sweet
# 1  Birds of a Feather      Billie Eilish      Hit Me Hard and Soft
# 2    Beautiful Things       Benson Boone  Fireworks & Rollerblades
#
#       Streams     Genre
# 0   980000000       Pop
# 1  1200000000       Pop
# 2  1100000000  Pop Rock

# %%
print(songs_data.columns)
# Out:
# Index(['Song', 'Artist', 'Album', 'Streams', 'Genre'], dtype='str')

# %%
songs_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Song     3 non-null      str
#  1   Artist   3 non-null      str
#  2   Album    3 non-null      str
#  3   Streams  3 non-null      int64
#  4   Genre    3 non-null      str
# dtypes: int64(1), str(4)
# memory usage: 252.0 bytes

# %%
songs_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Song     3 non-null      str
#  1   Artist   3 non-null      str
#  2   Album    3 non-null      str
#  3   Streams  3 non-null      int64
#  4   Genre    3 non-null      str
# dtypes: int64(1), str(4)
# memory usage: 252.0 bytes

# %%
df1 = pd.read_csv(r"C:\Users\mahek\Downloads\mydata\zomato.csv")

# %%
# Load TSV file
df1 = pd.read_csv(r"C:\Users\mahek\Downloads\mydata\zomato.csv", sep="\t")

# Generate summary statistics
print(df1.describe(include="all"))
# Out:
#        url,address,name,online_order,book_table,rate,votes,phone,location,rest_type,dish_liked,cuisines,approx_cost(for two people),reviews_list,menu_item,listed_in(type),listed_in(city)
# count                                               71730
# unique                                              71709
# top     +91 7259667270",Bannerghatta Road,Food Court,,...
# freq                                                    2

# %%
df = pd.read_csv(r"C:\Users\mahek\Downloads\aaa\flipkart_com-ecommerce_sample.csv")

df.to_excel(r"C:\Users\mahek\Downloads\aaa\flipkart_products.xlsx", index=False)

print("Excel file created successfully!")
# Out:
# Excel file created successfully!

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_excel(r"C:\Users\mahek\Downloads\aaa\flipkart_products.xlsx")

chunk_size = 2000

for i in range(0, len(df), chunk_size):
    chunk = df.iloc[i:i+chunk_size]
    print("Rows in this chunk:", len(chunk))
# Out:
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000
# Rows in this chunk: 2000

# %%
df = pd.read_csv(r"C:\Users\mahek\Downloads\bbbb\transactions.csv", sep=";")

missing = df.isnull().sum()
print(missing)
print("Columns with missing values:")
print(missing[missing > 0])
# Out:
# Transaction ID,Timestamp,Sender Name,Sender UPI ID,Receiver Name,Receiver UPI ID,Amount (INR),Status    0
# dtype: int64
# Columns with missing values:
# Series([], dtype: int64)

# %%
print(df.isnull().sum())
# Out:
# Transaction ID,Timestamp,Sender Name,Sender UPI ID,Receiver Name,Receiver UPI ID,Amount (INR),Status    0
# dtype: int64
