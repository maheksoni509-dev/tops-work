# %%
# 1. Instagram – Number of likes on a post → Numerical Data
# 2. Instagram – Type of content viewed (Reel, Story, Post) → Categorical Data
# 3. Zomato – Amount spent on an order → Numerical Data
# 4. Zomato – Type of cuisine ordered (Indian, Chinese, Italian) → Categorical Data
# 5. Flipkart – Number of products purchased → Numerical Data

# %%
# Data Type: Categorical Data
#  The data contains different music genres such as Pop, Rock, Jazz, and Hip-Hop.
# These are labels/categories and do not represent numerical values or quantities.

# %%
# Feature: Zomato restaurant rating
# Statistics can help by analyzing average ratings and user reviews.
# This can help Zomato recommend highly-rated restaurants and improve user experience.

# %%
# 1. Mean – Finds the average listening time of users.
#    Example Average listening time = 120 minutes per day.

# 2. Mode – Finds the most frequently played song.
#    Example  If Pop is played most often, Pop is the mode.

# 3. Variance – Measures how much users listening times differ.
#    Example  High variance means some users listen much more than others.
