# %%
play_counts = [120, 135, 150, 200, 120, 90, 200]

mean_plays = sum(play_counts) / len(play_counts)

print("Mean number of plays:", mean_plays)
# Out:
# Mean number of plays: 145.0

# %%
import statistics

delivery_times = [30, 25, 40, 35, 30, 45, 30]

median_time = statistics.median(delivery_times)

print("Median delivery time:", median_time)
# Out:
# Median delivery time: 30

# %%
def most_common_rating(ratings):
    return max(set(ratings), key=ratings.count)


ratings = [5, 4, 4, 3, 5, 4, 2, 4]

mode = most_common_rating(ratings)
print("Most common rating:", mode)
# Out:
# Most common rating: 4

# %%
import statistics

channel_A = [100, 120, 110, 105, 5000]  
channel_B = [100, 120, 110, 105, 115]
channel_C = [200, 210, 205, 215, 200]

def calculate_stats(data):
    mean = statistics.mean(data)
    median = statistics.median(data)
    mode = statistics.mode(data)
    return mean, median, mode

print("Channel A:", calculate_stats(channel_A))
print("Channel B:", calculate_stats(channel_B))
print("Channel C:", calculate_stats(channel_C))
# Out:
# Channel A: (1087, 110, 100)
# Channel B: (110, 110, 100)
# Channel C: (206, 205, 200)

# %%
import pandas as pd
import seaborn as sns
import statistics

df = sns.load_dataset("titanic")

age = df["age"].dropna()

mean_age = age.mean()
median_age = age.median()
mode_age = statistics.mode(age)

print("Mean age:", mean_age)
print("Median age:", median_age)
print("Mode age:", mode_age)
# Out:
# Mean age: 29.69911764705882
# Median age: 28.0
# Mode age: 24.0
