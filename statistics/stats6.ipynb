# %%
# H0: People spend equal or less time on Instagram than on YouTube daily.
# H1: People spend more time on Instagram than on YouTube daily.

# %%
from scipy.stats import ttest_ind_from_stats

t_stat, p_value = ttest_ind_from_stats(
    mean1=350, std1=50, nobs1=30,
    mean2=320, std2=50, nobs2=30
)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 2.32379000772445
# p-value: 0.023662215835435832

# %%
# !pip install scipy
# Out:
# ...
#   Using cached scipy-1.18.0-cp314-cp314-win_amd64.whl.metadata (61 kB)
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/37.3 MB 7.9 MB/s eta 0:00:05
#    - -------------------------------------- 1.6/37.3 MB 6.2 MB/s eta 0:00:06
#    -- ------------------------------------- 2.1/37.3 MB 4.8 MB/s eta 0:00:08
#    -- ------------------------------------- 2.4/37.3 MB 3.8 MB/s eta 0:00:10
#    -- ------------------------------------- 2.6/37.3 MB 3.0 MB/s eta 0:00:12
#    -- ------------------------------------- 2.6/37.3 MB 3.0 MB/s eta 0:00:12
#    --- ------------------------------------ 2.9/37.3 MB 2.4 MB/s eta 0:00:15
#    --- ------------------------------------ 3.1/37.3 MB 2.0 MB/s eta 0:00:18
#    --- ------------------------------------ 3.1/37.3 MB 2.0 MB/s eta 0:00:18
#    --- ------------------------------------ 3.1/37.3 MB 2.0 MB/s eta 0:00:18
# ...

# %%
# Feature: New Dark Mode in WhatsApp
#  Group (A): Users will use the existing light mode.
#  Group (B): Users will use the new dark mode.
#
# 
#  Average daily time spent on WhatsApp.
#
# H0: There is no significant difference in the average daily
#     time spent between the control and variant groups.
#
# H1: Users with the new dark mode spend significantly more
#     time on WhatsApp than users with the light mode.

# %%
# New button: 520 clicks out of 1000 users
# Old button: 480 clicks out of 1000 users
#
# The difference is 40 clicks, or 4%.
# Without detailed calculations, this difference is not enough
# to say that the new button is definitely better.
# It could be due to random chance.
#
# The p-value helps us decide:
# p-value < 0.05 → Difference is statistically significant → Reject H0.
# p-value > 0.05 → Difference may be due to chance → Fail to reject H0.
#
# Therefore, we need the p-value to make the final decision.
