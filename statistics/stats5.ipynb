# %%
# Example 1: Instagram Followers
# Population: A particular Instagram account ke all followers.
# Sample: Us account ke randomly selected 100 followers.


# Example 2: Zomato Restaurants
# Population: Ahmedabad ke all Zomato restaurants.
# Sample: Ahmedabad ke randomly selected 50 Zomato restaurants.


# Example 3: Flipkart Products
# Population: Flipkart par available all products.
# Sample: Analysis ke liye randomly selected 200 Flipkart products.

# %%
import random

users = [f"user{i}" for i in range(1, 1001)]

sample_users = random.sample(users, 50)

print("Selected survey users:")
print(sample_users)
# Out:
# Selected survey users:
# ['user658', 'user223', 'user753', 'user863', 'user81', 'user243', 'user436', 'user327', 'user758', 'user64', 'user390', 'user505', 'user114', 'user309', 'user687', 'user147', 'user912', 'user87', 'user760', 'user172', 'user480', 'user691', 'user764', 'user924', 'user787', 'user516', 'user890', 'user796', 'user70', 'user72', 'user386', 'user191', 'user356', 'user280', 'user127', 'user459', 'user679', 'user549', 'user911', 'user634', 'user738', 'user930', 'user128', 'user133', 'user907', 'user404', 'user45', 'user323', 'user575', 'user784']

# %%
# We use sampling because it is not possible to check the delivery time of every
# Swiggy order. Taking a smaller sample saves time and still gives us a good idea
# about the average delivery time.

# %%
# This introduces selection bias because the survey is only sent to users who
# recently streamed Bollywood songs. It does not include users with different
# music preferences, so the results may not represent all Spotify users.

# %%
# 1. Random Sampling:
# We can randomly select users from all BookMyShow users and ask them about
# their movie booking habits. This gives every user an equal chance of being selected.


# 2. Stratified Sampling:
# We can divide BookMyShow users into groups based on age, such as 18-25,
# 26-40, and 41+. Then we can randomly select some users from each group
# to make sure all age groups are represented in the sample.
